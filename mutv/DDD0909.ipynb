# %%
import pandas as pd

# %%
yxy_pitching = pd.read_csv('https://raw.githubusercontent.com/gcdean38/MSM_python/main/mutv/DDD0909.csv')

# %%
yxy_pitching.head()
# Out:
#    Year  Tms   #P  PAge   R/G   ERA     G    GF    CG   SHO  ...     BF  ERA+  \
# 0  2021   30  854  28.8  4.51  4.23  4070  0.99  0.01  0.01  ...  37.39   NaN
# 1  2020   30  735  28.3  4.65  4.44  1796  0.98  0.02  0.01  ...  37.03   NaN
# 2  2019   30  831  28.4  4.83  4.49  4858  0.99  0.01  0.01  ...  38.39   NaN
# 3  2018   30  799  28.4  4.45  4.14  4862  0.99  0.01  0.00  ...  38.08   NaN
# 4  2017   30  755  28.5  4.65  4.35  4860  0.99  0.01  0.01  ...  38.13   NaN
#
#     WHIP  BAbip   H9  HR9  BB9  SO9  SO/W     E
# 0  1.293  0.291  8.3  1.3  3.3  9.0  2.68  0.55
# 1  1.327  0.292  8.4  1.3  3.5  9.1  2.56  0.58
# 2  1.334  0.298  8.7  1.4  3.3  8.9  2.69  0.60
# 3  1.304  0.295  8.5  1.2  3.2  8.5  2.63  0.57
# 4  1.342  0.300  8.8  1.3  3.3  8.3  2.53  0.58
#
# [5 rows x 33 columns]

# %%
yxy_pitching.dtypes
# Out:
# Year       int64
# Tms        int64
# #P         int64
# PAge     float64
# R/G      float64
# ERA      float64
# G          int64
# GF       float64
# CG       float64
# SHO      float64
# tSho     float64
# SV       float64
# IP       float64
# H        float64
# R        float64
# ER       float64
# HR       float64
# BB       float64
# IBB      float64
# SO       float64
# HBP      float64
# BK       float64
# WP       float64
# BF       float64
# ERA+     float64
# WHIP     float64
# BAbip    float64
# H9       float64
# HR9      float64
# BB9      float64
# SO9      float64
# SO/W     float64
# E        float64
# dtype: object

# %%
yxy_pitching.plot.line(x="Year",y="SO9")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
yxy_pitching.plot.line(x="Year",y="SO/W")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
yxy_pitching.plot.line(x="Year",y="HR9")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
yxy_pitching.plot.line(x="Year",y="H9")
# Out:
# <AxesSubplot:xlabel='Year'>
