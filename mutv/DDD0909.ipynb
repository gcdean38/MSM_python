# %%
import pandas as pd
import numpy as np

# %%
yxy_pitching = pd.read_csv('https://raw.githubusercontent.com/gcdean38/MSM_python/main/mutv/DDD0909.csv')

# %% [markdown]
# ## Year by year pitching

# %%
yxy_pitching.head()
# Out:
#    Year  Tms   #P  PAge   R/G   ERA     G    GF    CG   SHO  ...     BF  ERA+  \
# 0  2021   30  854  28.8  4.51  4.23  4070  0.99  0.01  0.01  ...  37.39   NaN
# 1  2020   30  735  28.3  4.65  4.44  1796  0.98  0.02  0.01  ...  37.03   NaN
# 2  2019   30  831  28.4  4.83  4.49  4858  0.99  0.01  0.01  ...  38.39   NaN
# 3  2018   30  799  28.4  4.45  4.14  4862  0.99  0.01  0.00  ...  38.08   NaN
# 4  2017   30  755  28.5  4.65  4.35  4860  0.99  0.01  0.01  ...  38.13   NaN
#
#     WHIP  BAbip   H9  HR9  BB9  SO9  SO/W     E
# 0  1.293  0.291  8.3  1.3  3.3  9.0  2.68  0.55
# 1  1.327  0.292  8.4  1.3  3.5  9.1  2.56  0.58
# 2  1.334  0.298  8.7  1.4  3.3  8.9  2.69  0.60
# 3  1.304  0.295  8.5  1.2  3.2  8.5  2.63  0.57
# 4  1.342  0.300  8.8  1.3  3.3  8.3  2.53  0.58
#
# [5 rows x 33 columns]

# %%
yxy_pitching['decade'] = yxy_pitching['Year'].astype(str).str[:3]+"0s"
yxy_pitching.head(30)
# Out:
#     Year  Tms   #P  PAge   R/G   ERA     G    GF    CG   SHO  ...  ERA+  \
# 0   2021   30  854  28.8  4.51  4.23  4070  0.99  0.01  0.01  ...   NaN
# 1   2020   30  735  28.3  4.65  4.44  1796  0.98  0.02  0.01  ...   NaN
# 2   2019   30  831  28.4  4.83  4.49  4858  0.99  0.01  0.01  ...   NaN
# 3   2018   30  799  28.4  4.45  4.14  4862  0.99  0.01  0.00  ...   NaN
# 4   2017   30  755  28.5  4.65  4.35  4860  0.99  0.01  0.01  ...   NaN
# 5   2016   30  742  28.3  4.48  4.18  4856  0.98  0.02  0.01  ...   NaN
# 6   2015   30  735  28.4  4.25  3.95  4858  0.98  0.02  0.01  ...   NaN
# 7   2014   30  692  28.5  4.07  3.74  4860  0.98  0.02  0.01  ...   NaN
# 8   2013   30  679  28.4  4.17  3.86  4862  0.97  0.03  0.01  ...   NaN
# 9   2012   30  662  28.4  4.32  4.01  4860  0.97  0.03  0.01  ...   NaN
# 10  2011   30  662  28.3  4.28  3.94  4858  0.96  0.04  0.02  ...   NaN
# 11  2010   30  635  28.4  4.38  4.07  4860  0.97  0.03  0.01  ...   NaN
# ...

# %%
pitching_2000 = yxy_pitching[['Year','SO9']][:22]
pitching_2000['scale'] = pitching_2000['SO9']/(9.1)
pitching_2000
# Out:
#     Year  SO9     scale
# 0   2021  9.0  0.989011
# 1   2020  9.1  1.000000
# 2   2019  8.9  0.978022
# 3   2018  8.5  0.934066
# 4   2017  8.3  0.912088
# 5   2016  8.1  0.890110
# 6   2015  7.8  0.857143
# 7   2014  7.7  0.846154
# 8   2013  7.6  0.835165
# 9   2012  7.6  0.835165
# 10  2011  7.1  0.780220
# 11  2010  7.1  0.780220
# 12  2009  7.0  0.769231
# 13  2008  6.8  0.747253
# 14  2007  6.7  0.736264
# 15  2006  6.6  0.725275
# 16  2005  6.4  0.703297
# 17  2004  6.6  0.725275
# 18  2003  6.4  0.703297
# 19  2002  6.5  0.714286
# 20  2001  6.7  0.736264
# 21  2000  6.5  0.714286

# %%
pitching_svg = pitching_2000.plot.bar(x='Year',y='SO9')

# %%
dxd_pitching = yxy_pitching.groupby('decade')[['SO9','HR9','H9','SO/W','R/G']].mean()
dxd_pitching
# Out:
#              SO9       HR9         H9      SO/W       R/G
# decade
# 1870s   1.422222  0.111111  10.866667  1.883333  7.154444
# 1880s   3.570000  0.200000   9.150000  1.907000  5.423000
# 1890s   2.640000  0.260000  10.090000  0.780000  5.955000
# 1900s   3.480000  0.140000   8.670000  1.372000  4.080000
# 1910s   3.690000  0.170000   8.460000  1.250000  3.923000
# 1920s   3.110000  0.370000   9.840000  1.030000  4.921000
# 1930s   3.510000  0.510000   9.840000  1.084000  4.976000
# 1940s   3.710000  0.490000   9.020000  1.057000  4.393000
# 1950s   4.430000  0.840000   8.890000  1.244000  4.448000
# 1960s   5.710000  0.820000   8.450000  1.832000  4.053000
# 1970s   5.170000  0.750000   8.730000  1.560000  4.148000
# 1980s   5.360000  0.810000   8.860000  1.657000  4.289000
# 1990s   6.180000  0.950000   9.110000  1.790000  4.674000
# 2000s   6.620000  1.070000   9.190000  1.965000  4.759000
# 2010s   7.870000  1.090000   8.700000  2.522000  4.388000
# ...

# %%
yxy_pitching.dtypes
# Out:
# Year        int64
# Tms         int64
# #P          int64
# PAge      float64
# R/G       float64
# ERA       float64
# G           int64
# GF        float64
# CG        float64
# SHO       float64
# tSho      float64
# SV        float64
# IP        float64
# H         float64
# R         float64
# ER        float64
# HR        float64
# BB        float64
# IBB       float64
# SO        float64
# HBP       float64
# BK        float64
# WP        float64
# BF        float64
# ERA+      float64
# WHIP      float64
# BAbip     float64
# H9        float64
# HR9       float64
# BB9       float64
# SO9       float64
# SO/W      float64
# E         float64
# decade     object
# dtype: object

# %%
yxy_pitching.plot.line(x="Year",y="SO9")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
yxy_pitching.plot.line(x="Year",y="SO/W")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
yxy_pitching.plot.line(x="Year",y="HR9")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
yxy_pitching.plot.line(x="Year",y="H9")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
yxy_pitching.plot.line(x="Year",y="R/G")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
yxy_pitching.plot.line(x="Year",y="BB9")
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# ## Year by year batting

# %%
yxy_batting = pd.read_csv('https://raw.githubusercontent.com/gcdean38/MSM_python/main/mutv/DDD0909_1.csv')

# %%
yxy_batting = yxy_batting[['Year','R/G','G','PA','AB','R','H','HR','BB','SO','BA','OBP','SLG','OPS','TB']]

# %%
yxy_batting.dtypes
# Out:
# Year      int64
# R/G     float64
# G         int64
# PA        int64
# AB        int64
# R         int64
# H         int64
# HR        int64
# BB        int64
# SO        int64
# BA      float64
# OBP     float64
# SLG     float64
# OPS     float64
# TB        int64
# dtype: object

# %%
yxy_batting['decade'] = yxy_batting['Year'].astype(str).str[:3]+"0s"
yxy_batting.head(50)
# Out:
#     Year   R/G     G      PA      AB      R      H    HR     BB     SO  ...  \
# 0   2021  4.52  4124  154278  137394  18640  33371  5031  13437  35989  ...
# 1   2020  4.65  1796   66506   59030   8344  14439  2304   6092  15586  ...
# 2   2019  4.83  4858  186517  166651  23467  42039  6776  15895  42823  ...
# 3   2018  4.45  4862  185139  165432  21630  41018  5585  15686  41207  ...
# 4   2017  4.65  4860  185295  165567  22582  42215  6105  15829  40104  ...
# 5   2016  4.48  4856  184580  165561  21744  42276  5610  15088  38982  ...
# 6   2015  4.25  4858  183628  165488  20647  42106  4909  14073  37446  ...
# 7   2014  4.07  4860  183929  165614  19761  41595  4186  14020  37441  ...
# 8   2013  4.17  4862  184873  166070  20255  42093  4661  14640  36710  ...
# 9   2012  4.32  4860  184180  165251  21017  42063  4934  14709  36426  ...
# 10  2011  4.28  4858  185245  165705  20808  42267  4552  15018  34488  ...
# ...

# %%
yxy_batting['H_HR_pct'] = yxy_batting['HR'] / yxy_batting['H']
yxy_batting['SO_pct'] = yxy_batting['SO'] / yxy_batting['PA']
yxy_batting['H_pct'] = yxy_batting['H'] / yxy_batting['PA']
yxy_batting['BB_pct'] = yxy_batting['BB'] / yxy_batting['PA']
yxy_batting['HR_pct'] = yxy_batting['HR'] / yxy_batting['PA']

# %%
yxy_batting_csv = yxy_batting[['Year','H_HR_pct',"SO_pct",'H_pct','BB_pct','HR_pct','BA','SLG']]
yxy_batting_csv.to_csv('/Users/gcdyw9/Documents/github_python/MSM_python/mutv/yxy_batting.csv')

# %%
yxy_batting[:1]
# Out:
#    Year   R/G     G      PA      AB      R      H    HR     BB     SO  ...  \
# 0  2021  4.52  4124  154278  137394  18640  33371  5031  13437  35989  ...
#
#      OBP    SLG    OPS     TB  decade H_HR_pct    SO_pct     H_pct    BB_pct  \
# 0  0.317  0.409  0.726  56197   2020s  0.15076  0.233274  0.216304  0.087096
#
#     HR_pct
# 0  0.03261
#
# [1 rows x 21 columns]

# %%
yxy_batting[25:26]
# Out:
#     Year   R/G     G      PA      AB      R      H    HR     BB     SO  ...  \
# 25  1996  5.04  4534  177263  156801  22831  42320  4962  16093  29308  ...
#
#      OBP    SLG    OPS     TB  decade H_HR_pct    SO_pct     H_pct    BB_pct  \
# 25  0.34  0.427  0.767  66903   1990s  0.11725  0.165336  0.238741  0.090786
#
#       HR_pct
# 25  0.027992
#
# [1 rows x 21 columns]

# %%
batting_2000 = yxy_batting[['Year','H_pct','HR_pct','H_HR_pct','SO_pct']][:22]

# %%
batting_2000.plot.line(x="Year",y=['H_pct','HR_pct'])
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
batting_2000.plot.line(x="Year",y=['H_pct','HR_pct','H_HR_pct'])
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
batting_2000.plot.line(x="Year",y=['H_HR_pct'])
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
yxy_batting.plot.line(x="Year",y="H_HR_pct")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
yxy_batting.plot.line(x="Year",y=['SO_pct','BB_pct'])
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
yxy_batting.plot.line(x="Year",y=['H_pct','HR_pct','H_HR_pct'])
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
yxy_batting.plot.line(x="Year",y=['H_pct','HR_pct'])
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
yxy_batting.plot.line(x="Year",y=['HR_pct'])
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
yxy_batting.plot.line(x="Year",y=['SO_pct'])
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
r = np.corrcoef(yxy_batting['SO_pct'], yxy_batting['HR_pct'])
r
# Out:
# array([[1.        , 0.85500202],
#        [0.85500202, 1.        ]])

# %%
dxd_batting = yxy_batting.groupby('decade')[['R/G','H','HR','SO','BB','PA']].mean()
dxd_batting
# Out:
#              R/G             H           HR            SO            BB  \
# decade
# 1870s   7.154444   4809.222222    39.555556    665.444444    336.777778
# 1880s   5.423000  15572.200000   377.300000   4253.900000   3781.800000
# 1890s   5.955000  18273.200000   476.600000   4583.400000   6272.300000
# 1900s   4.077000  19104.800000   309.800000   7940.900000   5571.400000
# 1910s   3.925000  22428.000000   453.200000   9828.700000   7818.700000
# 1920s   4.929000  31937.300000  1350.500000   6940.900000   9902.500000
# 1930s   4.975000  27625.600000  1502.600000   8165.800000   9142.600000
# 1940s   4.397000  25390.500000  1410.800000   8779.900000   9950.700000
# 1950s   4.447000  21877.400000  2086.000000  10878.400000   8820.900000
# 1960s   4.053000  26864.700000  2616.900000  18243.100000  10004.600000
# 1970s   4.148000  34443.200000  2954.300000  20374.100000  13077.000000
# 1980s   4.289000  35886.600000  3294.200000  21814.700000  13116.400000
# ...

# %%
dxd_batting['H_HR_pct'] = dxd_batting['HR'] / dxd_batting['H']
dxd_batting['SO_pct'] = dxd_batting['SO'] / dxd_batting['PA']
dxd_batting['H_pct'] = dxd_batting['H'] / dxd_batting['PA']
dxd_batting['BB_pct'] = dxd_batting['BB'] / dxd_batting['PA']
dxd_batting['HR_pct'] = dxd_batting['HR'] / dxd_batting['PA']
decade_list = [1870,1880,1890,1900,1910,1920,1930,1940,1950,1960,1970,1980,1990,2000,2010,2020]

# %%
dxd_batting['decade_num'] = decade_list
dxd_batting
# Out:
#              R/G             H           HR            SO            BB  \
# decade
# 1870s   7.154444   4809.222222    39.555556    665.444444    336.777778
# 1880s   5.423000  15572.200000   377.300000   4253.900000   3781.800000
# 1890s   5.955000  18273.200000   476.600000   4583.400000   6272.300000
# 1900s   4.077000  19104.800000   309.800000   7940.900000   5571.400000
# 1910s   3.925000  22428.000000   453.200000   9828.700000   7818.700000
# 1920s   4.929000  31937.300000  1350.500000   6940.900000   9902.500000
# 1930s   4.975000  27625.600000  1502.600000   8165.800000   9142.600000
# 1940s   4.397000  25390.500000  1410.800000   8779.900000   9950.700000
# 1950s   4.447000  21877.400000  2086.000000  10878.400000   8820.900000
# 1960s   4.053000  26864.700000  2616.900000  18243.100000  10004.600000
# 1970s   4.148000  34443.200000  2954.300000  20374.100000  13077.000000
# 1980s   4.289000  35886.600000  3294.200000  21814.700000  13116.400000
# ...

# %%
0.033223/0.028087
# Out:
# 1.1828603980489194

# %%
0.233599/0.205487
# Out:
# 1.1368067079669273

# %%
0.088453/0.081526
# Out:
# 1.084966759070726

# %%
dxd_batting.plot.line(x='decade_num',y=['H_pct','HR_pct','H_HR_pct'])
# Out:
# <AxesSubplot:xlabel='decade_num'>

# %% [markdown]
# ## Animated Time Series
