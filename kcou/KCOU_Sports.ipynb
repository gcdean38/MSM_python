# %%
import pandas as pd

# %% [markdown]
# ## Women's Soccer vs Nebraska (Aug 22, 2021)

# %%
wsoc_nebraska = pd.read_excel('/Users/geoffrey/Documents/KCOU_sports/KCOU.xlsx', sheet_name = '0822WSocNebraska')

# %%
wsoc_nebraska
# Out:
#              season_21           season_20           season_19  \
# 0         Sophia Worth        Sophia Worth       Peyton Bauman
# 1      McKenna Sheehan     McKenna Sheehan     McKenna Sheehan
# 2       Eryka McIntyre      Eryka McIntyre      Eryka McIntyre
# 3         Jadyn Easley        Jadyn Easley        Jadyn Easley
# 4          Kylie Dobbs        Bella Alessi        Bella Alessi
# 5      Jenna McCormick         Grace Kitts         Grace Kitts
# 6          Kyra Reeves         Kyra Reeves          Anna Frick
# 7       Blythe Beldner      Blythe Beldner      Blythe Beldner
# 8   Cassidy Nurnberger  Cassidy Nurnberger  Cassidy Nurnberger
# 9       Milena Fischer           Zoe Cross           Zoe Cross
# 10        Avery Brandt    Lindsey Whitmore    Lindsey Whitmore
# 11        Ashlyn Mills       Keiarra Slack     Janna Singleton
# 12           Leah Selm        Kyla Johnson       Keiarra Slack
# 13        Kyla Johnson    Julissa Cisneros        Kyla Johnson
# 14    Julissa Cisneros         Kloee Grubb    Julissa Cisneros
# 15        Grace Pettet        Grace Pettet       Peyton Joseph
# 16       Hannah Joella       Hannah Joella      Sarah Luebbert
# 17       Macy Trujillo       Macy Trujillo       Macy Trujillo
# 18       Jenna Bartels       Jenna Bartels       Skye Kingsley
# 19       Skye Kingsley       Skye Kingsley        Izzy Coulter
# 20     Madilyn Hamline     Madilyn Hamline        Morgan Davis
# 21        Morgan Davis        Morgan Davis  Morcquess Oliphant
# 22       Haley Steinke  Morcquess Oliphant       Haley Steinke
# 23        Gia Woodfolk       Haley Steinke         Briana Abam
# 24       Megan Oduyoye       Megan Oduyoye       Megan Oduyoye
# 25    Isabella Alessio    Isabella Alessio       Madison Lewis
# 26     Momola Adesanmi     Momola Adesanmi          Megan Moll
# 27      Caroline Lyman      Caroline Lyman     Momola Adesanmi
# 28    Bella Hollenbach                 NaN      Caroline Lyman
# 29                 NaN                 NaN     Gillian Schulte
# 30                  29                  28                  30
#
#              season_18           season_17          season_16  \
# 0        Peyton Bauman       Peyton Bauman      Kelsey Dossey
# 1        Kelsey Dossey       Kelsey Dossey    Lauren Selaiden
# 2         Bella Alessi      Brynne Polivka    Payton Goulding
# 3          Grace Kitts     Payton Goulding          Erin Webb
# 4           Anna Frick        Bella Alessi        Grace Kitts
# 5       Blythe Beldner         Grace Kitts         Anna Frick
# 6   Cassidy Nurnberger          Anna Frick      Kaitlyn Clark
# 7        Bethany Coons       Kaitlyn Clark     Rachel Hignett
# 8            Zoe Cross  Cassidy Nurnberger      Bethany Coons
# 9     Lindsey Whitmore       Bethany Coons  Melanie Donaldson
# 10       Keiarra Slack           Zoe Cross         Lizzy Akre
# 11         Rachel Hise    Lindsey Whitmore        Rachel Hise
# 12    Julissa Cisneros       Tess Rellihan     Kristen Rivers
# 13       Peyton Joseph          Lizzy Akre      Peyton Joseph
# 14      Sarah Luebbert         Rachel Hise     Sarah Luebbert
# 15      Ariela Beharry      Kristen Rivers  Natalie McDonough
# 16       Macy Trujillo       Peyton Joseph  Savannah Trujillo
# 17    Hailey Blanchard      Sarah Luebbert         Allie Hess
# 18       Skye Kingsley       Macy Trujillo       Izzy Coulter
# 19        Izzy Coulter   Savannah Trujillo    Jasmine Johnson
# 20  Morcquess Oliphant          Allie Hess    Jessica Johnson
# 21       Lauren Gaston        Izzy Coulter      Lauren Gaston
# 22       Madison Lewis  Morcquess Oliphant         Erin Jones
# 23     Momola Adesanmi     Jessica Johnson      Madison Lewis
# 24       Mercedes Sapp       Lauren Gaston      Mercedes Sapp
# 25                 NaN       Madison Lewis                NaN
# 26                 NaN     Momola Adesanmi                NaN
# 27                 NaN       Mercedes Sapp                NaN
# 28                 NaN                 NaN                NaN
# 29                 NaN                 NaN                NaN
# 30                  25                  28                 25
#
#             season_15  Unnamed: 7  Unnamed: 8     Unnamed: 9    season_21.1  \
# 0       Kelsey Dossey         NaN         NaN      returners             21
# 1     Lauren Selaiden         NaN         NaN  total_players             29
# 2     Payton Goulding         NaN         NaN     return_pct       0.724138
# 3           Erin Webb         NaN         NaN    new_players              8
# 4     Brittany Conley         NaN         NaN   lost_players              7
# 5      Reagan Russell         NaN         NaN            win            NaN
# 6       Kaitlyn Clark         NaN         NaN           loss            NaN
# 7      Rachel Hignett         NaN         NaN            tie            NaN
# 8       Bethany Coons         NaN         NaN            pts              0
# 9   Melanie Donaldson         NaN         NaN        win_pct            NaN
# 10       Lauren Flynn         NaN         NaN            NaN            NaN
# 11    Macee Blanchard         NaN         NaN            NaN            NaN
# 12         Lizzy Akre         NaN         NaN            NaN      returners
# 13        Rachel Hise         NaN         NaN            NaN  total_players
# 14     Kristen Rivers         NaN         NaN            NaN     return_pct
# 15     Alli Magaletta         NaN         NaN            NaN    new_players
# 16        Amanda Shaw         NaN         NaN            NaN   lost_players
# 17  Natalie McDonough         NaN         NaN            NaN            win
# 18  Savannah Trujillo         NaN         NaN            NaN           loss
# 19         Allie Hess         NaN         NaN            NaN            tie
# 20    Candace Johnson         NaN         NaN            NaN            pts
# 21    Jessica Herrman         NaN         NaN            NaN            NaN
# 22      Taylor Walker         NaN         NaN            NaN            NaN
# 23    Jasmine Johnson         NaN         NaN            NaN            NaN
# 24    Jessica Johnson         NaN         NaN            NaN            NaN
# 25      Lauren Gaston         NaN         NaN            NaN            NaN
# 26      Madison Lewis         NaN         NaN            NaN            NaN
# 27                NaN         NaN         NaN            NaN            NaN
# 28                NaN         NaN         NaN            NaN            NaN
# 29                NaN         NaN         NaN            NaN            NaN
# 30                 27         NaN         NaN            NaN            NaN
#
#    season_20.1 season_19.1 season_18.1 season_17.1 season_16.1  season_15.1  \
# 0           20          18          19          18          18          NaN
# 1           28          30          25          28          25         27.0
# 2     0.714286         0.6        0.76    0.642857        0.72          NaN
# 3            8          12           6          10           7          NaN
# 4           10           7           9           7           9          NaN
# 5            6           7           6           8          11          NaN
# 6            5          10          11          12           7          NaN
# 7            3           1           2           1           2          NaN
# 8           21          22          20          25          35          NaN
# 9     0.545455         NaN         NaN         NaN         NaN          NaN
# 10         NaN         NaN         NaN         NaN         NaN          NaN
# 11   season_20   season_19   season_18   season_17   season_16          NaN
# 12          20          18          19          18          18          NaN
# 13          28          30          25          28          25          NaN
# 14    0.714286         0.6        0.76    0.642857        0.72          NaN
# 15           8          12           6          10           7          NaN
# 16          10           7           9           7           9          NaN
# 17           6           7           6           8          11          NaN
# 18           5          10          11          12           7          NaN
# 19           3           1           2           1           2          NaN
# 20          21          22          20          25          35          NaN
# 21         NaN         NaN         NaN         NaN         NaN          NaN
# 22         NaN         NaN         NaN         NaN         NaN          NaN
# 23         NaN         NaN         NaN         NaN         NaN          NaN
# 24         NaN         NaN         NaN         NaN         NaN          NaN
# 25         NaN         NaN         NaN         NaN         NaN          NaN
# 26         NaN         NaN         NaN         NaN         NaN          NaN
# 27         NaN         NaN         NaN         NaN         NaN          NaN
# 28         NaN         NaN         NaN         NaN         NaN          NaN
# 29         NaN         NaN         NaN         NaN         NaN          NaN
# 30         NaN         NaN         NaN         NaN         NaN          NaN
#
#     Unnamed: 17
# 0     -0.540036
# 1     -0.426722
# 2      0.074620
# 3     -0.183567
# 4      0.024408
# 5      0.990958
# 6     -0.238685
# 7     -0.068496
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# 30          NaN

# %%
seasons_custom = pd.DataFrame(wsoc_nebraska, columns = ['season_20','season_20'])

# %%
seasons_custom
# Out:
#              season_20           season_20
# 0         Sophia Worth        Sophia Worth
# 1      McKenna Sheehan     McKenna Sheehan
# 2       Eryka McIntyre      Eryka McIntyre
# 3         Jadyn Easley        Jadyn Easley
# 4         Bella Alessi        Bella Alessi
# 5          Grace Kitts         Grace Kitts
# 6          Kyra Reeves         Kyra Reeves
# 7       Blythe Beldner      Blythe Beldner
# 8   Cassidy Nurnberger  Cassidy Nurnberger
# 9            Zoe Cross           Zoe Cross
# 10    Lindsey Whitmore    Lindsey Whitmore
# 11       Keiarra Slack       Keiarra Slack
# 12        Kyla Johnson        Kyla Johnson
# 13    Julissa Cisneros    Julissa Cisneros
# 14         Kloee Grubb         Kloee Grubb
# 15        Grace Pettet        Grace Pettet
# 16       Hannah Joella       Hannah Joella
# 17       Macy Trujillo       Macy Trujillo
# 18       Jenna Bartels       Jenna Bartels
# 19       Skye Kingsley       Skye Kingsley
# 20     Madilyn Hamline     Madilyn Hamline
# 21        Morgan Davis        Morgan Davis
# 22  Morcquess Oliphant  Morcquess Oliphant
# 23       Haley Steinke       Haley Steinke
# 24       Megan Oduyoye       Megan Oduyoye
# 25    Isabella Alessio    Isabella Alessio
# 26     Momola Adesanmi     Momola Adesanmi
# 27      Caroline Lyman      Caroline Lyman
# 28                 NaN                 NaN
# 29                 NaN                 NaN
# 30                  28                  28

# %%
seasons_custom['returner'].value_counts()
# Out:
# True     18
# False    13
# Name: returner, dtype: int64

# %%
seasons_custom = pd.DataFrame(wsoc_nebraska, columns = ['season_19','season_18'])
seasons_custom['returner'] = wsoc_nebraska['season_19'].isin(wsoc_nebraska['season_18'])

# %%
seasons_custom[seasons_custom['returner']==False]['season_18'].shape
# Out:
# (13,)

# %%
seasons_custom[seasons_custom['returner']==False]
# Out:
#           season_19           season_18  returner
# 1   McKenna Sheehan       Kelsey Dossey     False
# 2    Eryka McIntyre        Bella Alessi     False
# 3      Jadyn Easley         Grace Kitts     False
# 11  Janna Singleton         Rachel Hise     False
# 13     Kyla Johnson       Peyton Joseph     False
# 20     Morgan Davis  Morcquess Oliphant     False
# 22    Haley Steinke       Madison Lewis     False
# 23      Briana Abam     Momola Adesanmi     False
# 24    Megan Oduyoye       Mercedes Sapp     False
# 26       Megan Moll                 NaN     False
# 28   Caroline Lyman                 NaN     False
# 29  Gillian Schulte                 NaN     False
# 30               30                  25     False

# %% [markdown]
# ### Model Building

# %%
import numpy as np

# %%
model_data = pd.read_excel('/Users/geoffrey/Documents/KCOU_sports/KCOU.xlsx', sheet_name = 'model_data')

# %%
predictors = pd.DataFrame(model_data, columns = ['returners','total_players','return_pct','new_players','lost_players','roster_size_change','turnover'])

# %%
target = pd.DataFrame(model_data, columns=['pts'])

# %%
import statsmodels.api as sm
from sklearn import linear_model

# %%
X = predictors
y = target['pts']

# %%
lm = linear_model.LinearRegression()
model = lm.fit(X,y)

# %%
predictions = lm.predict(X)
print(predictions)
# Out:
# [21. 22. 20. 25. 35.]

# %%
lm.score(X,y)
# Out:
# 1.0

# %%
lm.coef_
# Out:
# array([ -13.01395187,    8.3472852 , -637.17948718,   -2.60659492,
#          -2.18719095,  -14.96394062,   -5.93059582])

# %%
lm.intercept_
# Out:
# 622.2307692307858

# %% [markdown]
# ## Attempt to build scraper

# %%
from urllib.request import urlopen

# %%
from bs4 import BeautifulSoup

# %%
url = 'https://mutigers.com/sports/womens-soccer/roster/2021'

# %%
page = urlopen(url)
html = page.read().decode('utf-8')
soup = BeautifulSoup(html, "html.parser")

# %%
last_names = soup.find_all('span',{'class':"sidearm-roster-player-last-name"})

# %%
for last_name in last_names:
    last_name.text
    #print(last_name.text)

# %%
years = []
for year in range(1996,2022):
    years.append(str(year))

# %%
base_url_miz = 'https://mutigers.com/sports/womens-soccer/roster/'
urls_miz = []
for year in years:
    url_test_miz = base_url_miz+year
    urls_miz.append(url_test_miz)

# %%
print(urls_miz)
# Out:
# ['https://mutigers.com/sports/womens-soccer/roster/1996', 'https://mutigers.com/sports/womens-soccer/roster/1997', 'https://mutigers.com/sports/womens-soccer/roster/1998', 'https://mutigers.com/sports/womens-soccer/roster/1999', 'https://mutigers.com/sports/womens-soccer/roster/2000', 'https://mutigers.com/sports/womens-soccer/roster/2001', 'https://mutigers.com/sports/womens-soccer/roster/2002', 'https://mutigers.com/sports/womens-soccer/roster/2003', 'https://mutigers.com/sports/womens-soccer/roster/2004', 'https://mutigers.com/sports/womens-soccer/roster/2005', 'https://mutigers.com/sports/womens-soccer/roster/2006', 'https://mutigers.com/sports/womens-soccer/roster/2007', 'https://mutigers.com/sports/womens-soccer/roster/2008', 'https://mutigers.com/sports/womens-soccer/roster/2009', 'https://mutigers.com/sports/womens-soccer/roster/2010', 'https://mutigers.com/sports/womens-soccer/roster/2011', 'https://mutigers.com/sports/womens-soccer/roster/2012', 'https://mutigers.com/sports/womens-soccer/roster/2013', 'https://mutigers.com/sports/womens-soccer/roster/2014', 'https://mutigers.com/sports/womens-soccer/roster/2015', 'https://mutigers.com/sports/womens-soccer/roster/2016', 'https://mutigers.com/sports/womens-soccer/roster/2017', 'https://mutigers.com/sports/womens-soccer/roster/2018', 'https://mutigers.com/sports/womens-soccer/roster/2019', 'https://mutigers.com/sports/womens-soccer/roster/2020', 'https://mutigers.com/sports/womens-soccer/roster/2021']

# %%
name_df_test

# %%
name_df_test_miz = pd.DataFrame(index = range(0,30))
for url_test_miz in urls_miz:
    # empty year list
    raw_list_test = []
    
    # Set up parser
    page_test = urlopen(url_test_miz)
    html_test = page_test.read().decode('utf-8')
    soup_test = BeautifulSoup(html_test,"html.parser")
    
    # Get last names
    names_test = soup_test.find_all('a',{'class':"sidearm-roster-player-name"})

    year_test_pull = soup_test.find('title')
    year_test = year_test_pull.text[3:7]
    for name_test in names_test:
        raw_list_test.append(name_test.text)
        
    year_list_test = []
    for year_item_test in raw_list_test:
        year_item_test_strip = year_item_test.strip()
        year_list_test.append(year_item_test_strip.replace('\n',"_"))
    print(year_list_test)
    name_df_test_miz[year_test+'_season'] = pd.Series(year_list_test)
# Out:
# ['Heather_Arney', 'Amy_Haines', 'Grace_Blum', 'Jennifer_Kram', 'Heather_Buchheit', 'Erin_Cummins', 'Melissa_Bell', 'Kate_Dwyer', 'Stephanie_Bodine', 'Andrea_Czarnik', 'Sharon_Wirkus', 'Jamie _Miller', 'Jennifer _Murphy', 'Robin_Neumann', "Jennifer _O'Donnell", 'Robyn_Reeb', 'Liz_Passanise', 'Angela_Doss', 'Sarah_Taylor', 'Sarah_Whiting', 'Melissa_Grinstead', 'Elizabeth_LaTour', 'Jessica_Graczyk', 'Bryan_Blitz']
# ['Nikki_Thole', 'Amy _Timmermann', 'Jennifer_Kram', 'Heather_Buchheit', 'Laura_McKenna', 'Kate_Dwyer', 'Mandy_Waters', 'Andrea_Czarnik', 'Jennifer_Maunder', 'Kristin_Boeker', 'Becky_Paulsen', "Jennifer _O'Donnell", 'Robyn_Reeb', 'Liz_Passanise', 'Angela_Doss', 'Jackie_Adamec', 'Elizabeth_LaTour', 'Jessica_Graczyk', 'Erin_Waller', 'Bryan_Blitz']
# ['Dyana_Russell', 'Nikki_Thole', 'Amy _Timmermann', 'Jennifer_Kram', 'Sarah_Sallee', 'Heather_Buchheit', 'Laura_McKenna', 'Kate_Dwyer', 'Mandy_Waters', 'Andrea_Czarnik', 'Whitney_Blackmar', 'Jennifer_Maunder', 'Kristin_Boeker', 'Becky_Paulsen', 'Michelle_Hindman', 'Erin_Grimsley', 'Liz_Passanise', 'Shelly_DonMoyer', 'Stephanie_Brennan', 'Jackie_Adamec', 'Elizabeth_LaTour', 'Graham_Watson', 'Jessica_Graczyk', 'Bryan_Blitz']
# ['Dyana_Russell', 'Nikki_Thole', 'Amy _Timmermann', 'Jennifer_Kram', 'Sarah_Sallee', 'Heather_Buchheit', "Amy_O'Leary", 'Kate_Dwyer', 'Mandy_Waters', 'Mandy_Pavlovits', 'Suzanne_Probst', 'Tamisha _Ellis', 'Kristin_Boeker', 'Becky_Paulsen', 'Michelle_Hindman', 'Laura_Smith', 'Erin_Grimsley', 'Kathleen_Wiley', 'Liz_Passanise', 'Shelly_DonMoyer', 'Stephanie_Brennan', 'Jackie_Adamec', 'Elizabeth_LaTour', 'Graham_Watson', 'Jessica_Graczyk', 'Bryan_Blitz']
# ['Dyana_Russell', 'Nikki_Thole', 'Amy _Timmermann', 'Karen_Bauer', 'Sarah_Sallee', 'Adriene_Davis', 'Kristin_Gibbons', 'Amanda_Williams', 'Mandy_Waters', 'Suzanne_Probst', 'Tamisha _Ellis', 'Kristin_Boeker', 'Becky_Paulsen', 'Michelle_Hindman', 'Laura_Smith', 'Jennifer_McMaster', 'Kathleen_Wiley', 'Melissa_McLellan', 'Shelly_DonMoyer', 'Stephanie_Brennan', 'Megan_Duncan', 'Graham_Watson', 'Jessica_Graczyk', 'Carey _Patton', 'Stephanie _Krawczyk', 'Bryan_Blitz']
# ['Dyana_Russell', 'Carrie_Crossett', 'Dallas_Bird', 'Karen_Bauer', 'Adriene_Davis', 'Kristin_Gibbons', 'Ashley_Gibbs', 'Mandy_Waters', 'Colleen_Macarthy', 'Suzanne_Probst', 'Kristin_Heil', 'Lacy_Moore', 'Kim_Hibbert', 'Angela_Furin', 'Melissa _Peabody', 'Melissa_McLellan', 'Shea_Swoboda', 'Stephanie_Brennan', 'Tamara_Kochen', 'Emma Kate_Young', 'Megan_Duncan', 'Stephanie _Krawczyk', 'Bryan_Blitz']
# ['Carrie_Crossett', 'Breanah_Glynn', 'Karen_Bauer', 'Adriene_Davis', 'Kristin_Gibbons', 'Erica_Pusch', 'Ashley_Gibbs', 'Jennifer_Nobis', 'Amber_Swinehart', 'Suzanne_Probst', 'Kristin_Heil', 'Lacy_Moore', 'Kim_Hibbert', 'Angela_Furin', 'Melissa _Peabody', 'Kylie_Wilson', 'Melissa_McLellan', 'Shea_Swoboda', 'Kylie_Moorman', 'Tamara_Kochen', 'Emma Kate_Young', 'Megan_Duncan', 'Stephanie _Krawczyk', 'Bryan_Blitz']
# ['Kira_Reyes', 'Mallory_Ames', 'Karen_Bauer', 'Adriene_Davis', 'Kristin_Gibbons', 'Erica_Pusch', 'Ashley_Gibbs', 'Jennifer_Nobis', 'Amber_Swinehart', 'Elyse_Nikonchuck', 'Kristin_Heil', 'Lacy_Moore', 'Kim_Hibbert', 'Melissa_Griggs', 'Melissa _Peabody', 'Aria_Hudetz', 'Melissa_McLellan', 'Shea_Swoboda', 'Margaret_Malm', 'Lauren_Grice', 'Megan_Duncan', 'Stephanie _Krawczyk', 'Bryan_Blitz']
# ['Kira_Reyes', 'Mallory_Ames', 'Beth_Wheeler', 'Karen_Bauer', 'Megan_Smith', 'Casey_Dreyfus', 'Jenna_Lind', 'Erica_Pusch', 'Ashley_Gibbs', 'Jennifer_Nobis', 'Amber_Swinehart', 'Elyse_Nikonchuck', 'Kristin_Heil', 'Lacy_Moore', 'Laura_Buehrig', 'Melissa _Peabody', 'Aria_Hudetz', 'Maddie_Senkosky', 'Shea_Swoboda', 'Lauren_Grice', 'Margaret_Malm', 'Lauren_Vineyard', 'Bryan_Blitz']
# ['Kira_Reyes', 'Mallory_Ames', 'Meghan_Pfeiffer', 'Lindsay_McCoy', 'Anne_Baxter', 'Casey_Dreyfus', 'Erica_Pusch', 'Beth_Warwick', 'Jennifer_Nobis', 'Amber_Swinehart', 'Elyse_Nikonchuck', 'Mo_Redmond', 'Janelle_Cordia', 'Caroline_Pohl', 'Laura_Buehrig', 'Aria_Hudetz', 'Maddie_Senkosky', 'Kat_Tarr', 'Ashley_Hamblin', 'Lauren_Grice', 'Margaret_Malm', 'Mallory_Frost', 'Lauren_Vineyard', 'Annie_Meredith', 'Bryan_Blitz']
# ['Bree_Thornton', 'Meghan_Pfeiffer', 'Lindsay_McCoy', 'Anne_Baxter', 'Katya _Hessel', 'Crystal_Wagner', 'Bianca_Pritchett', 'Elyse_Nikonchuck', 'Mo_Redmond', 'Janelle_Cordia', 'Michelle_Collins', 'Kristin_Andrighetto', 'Aria_Hudetz', 'Maddie_Senkosky', 'Kat_Tarr', 'Ashley_Hamblin', 'Lauren_Grice', 'Margaret_Malm', 'Mallory_Frost', 'Paula_Jackson', 'Bryan_Blitz']
# ['Bree_Thornton', 'Meghan_Pfeiffer', 'Lindsay_McCoy', 'Kari_Adam', 'Katya _Hessel', 'Crystal_Wagner', 'Krista_Kruse', 'Alysha _Bonnick', 'Mo_Redmond', 'Janelle_Cordia', 'Michelle_Collins', 'Tasha_Dittamore', 'Kristin_Andrighetto', 'Caitlin_Linas', 'Brittany_Hopkins', 'Kat_Tarr', 'Ashley_Hamblin', 'Kelsey_Stokes', 'Mallory_Frost', 'Emily_Zaler', 'Bryan_Blitz']
# ['Bree_Thornton', 'Meghan_Pfeiffer', 'Lindsay_McCoy', 'Kari_Adam', 'Mallory_Stipetich', 'Crystal_Wagner', 'Krista_Kruse', 'Jessie_Crabtree', 'Alysha _Bonnick', 'Mo_Redmond', 'Janelle_Cordia', 'Michelle_Collins', 'Tasha_Dittamore', 'Kristin_Andrighetto', 'Kelsey_Blincow', 'Brittany_Hopkins', 'Kat_Tarr', 'Ashley_Hamblin', 'Kelsey_Stokes', 'Kendra_Collins', 'Mallory_Frost', 'Liz_Gayer', 'Candace_Ruff', 'Bryan_Blitz']
# ['Jessica_Gwin', 'Bree_Thornton', 'Meghan_Pfeiffer', 'Haley_Krentz', 'Kari_Adam', 'Mallory_Stipetich', 'Molly_Sylvester', 'Crystal_Wagner', 'Krista_Kruse', 'Jessie_Crabtree', 'Alysha _Bonnick', 'Sarah_Thune', 'Michelle_Collins', 'Tasha_Dittamore', 'Kristin_Andrighetto', 'Kelsey_Blincow', 'Brittany_Hopkins', 'Jessica_Greer', 'Kelsey_Mulcahy', 'Kelsey_Stokes', 'Kendra_Collins', 'Liz_Gayer', 'Candace_Ruff', 'Edith_Lopez', 'Bryan_Blitz']
# ['McKenzie_Sauerwein', 'Jessica_Gwin', 'Dominique_Richardson', 'Haley_Krentz', 'Kari_Adam', 'Mallory_Stipetich', 'Danielle_Nottingham', 'Krista_Kruse', 'Jessie_Crabtree', 'Alysha_Bonnick', 'Sarah_Thune', 'Alyssa_Diggs', 'Molly_Bear', 'Kelsey_Blincow', 'Brittany_Hopkins', 'Jessica_Greer', 'Kelsey_Mulcahy', 'Paula_Pritzen', 'Kendra_Collins', 'Alex_Charlebois', 'Bryan_Blitz']
# ['McKenzie_Sauerwein', 'Dominique_Richardson', 'Brooke_Williams', 'Haley_Krentz', 'Brittany_Conley', 'Mallory_Stipetich', 'Taiwo_Adeshigbin', 'Danielle_Nottingham', 'Kaysie_Clark', 'Sydnie_Green', 'Lauren_Flynn', 'Catherine_Birch', 'Sarah_Thune', 'Alyssa_Diggs', 'Allison_Hu', 'Kelsey_Blincow', 'Taylor_Grant', 'Jessica_Greer', 'Kelsey_Mulcahy', 'Abi_Raymer', 'Kendra_Collins', 'Chelsea_Smith', 'Brittanee_Randle', 'Bryan_Blitz']
# ['McKenzie_Sauerwein', 'Dominique_Richardson', 'Brooke_Williams', 'Haley_Krentz', 'Brittany_Conley', 'Reagan_Russell', 'Taiwo_Adeshigbin', 'Danielle_Nottingham', 'Kaysie_Clark', 'Lauren_Flynn', 'Macee_Blanchard', 'Sarah_Thune', 'Alyssa_Diggs', 'Allison_Hu', 'Kaz_James', 'Loudell_Crumpler', 'Taylor_Grant', 'Jessica_Greer', 'Kelsey_Mulcahy', 'Abi_Raymer', 'Candace_Johnson', 'Jessica_Herrman', 'Shelby_Sonnefeldt', 'Brittanee_Randle', 'Bryan_Blitz']
# ['McKenzie_Sauerwein', 'Dominique_Richardson', 'Brooke_Williams', 'Erin_Webb', 'Brittany_Conley', 'Reagan_Russell', 'Danielle_Nottingham', 'Kaysie_Clark', 'Melanie_Donaldson', 'Lauren_Flynn', 'Macee_Blanchard', 'Sarah_Thune', 'Alyssa_Diggs', 'Kristen_Rivers', 'Kaz_James', 'Taylor_Grant', 'Rachel_Hignett', 'Candace_Johnson', 'Jessica_Herrman', 'Lauren_Selaiden', 'Jasmine_Johnson', 'Brittanee_Randle', 'Bryan_Blitz']
# ['McKenzie_Sauerwein', 'Lauren_Selaiden', 'Erin_Webb', 'Brittany_Conley', 'Reagan_Russell', 'Kaitlyn_Clark', 'Rachel_Hignett', 'Kaysie_Clark', 'Melanie_Donaldson', 'Lauren_Flynn', 'Macee_Blanchard', 'Lizzy_Akre', 'Kristen_Rivers', 'Kaz_James', 'Alli_Magaletta', 'Taylor_Grant', 'Savannah_Trujillo', 'Allie_Hess', 'Candace_Johnson', 'Jessica_Herrman', 'Taylor_Walker', 'Jasmine_Johnson', 'Jessica_Johnson', 'Lauren_Gaston', 'Brittanee_Randle', 'Bryan_Blitz']
# ['Kelsey_Dossey', 'Lauren_Selaiden', 'Payton_Goulding', 'Erin_Webb', 'Brittany_Conley', 'Reagan_Russell', 'Kaitlyn_Clark', 'Rachel_Hignett', 'Bethany_Coons', 'Melanie_Donaldson', 'Lauren_Flynn', 'Macee_Blanchard', 'Lizzy_Akre', 'Rachel_Hise', 'Kristen_Rivers', 'Alli_Magaletta', 'Amanda_Shaw', 'Natalie_McDonough', 'Savannah_Trujillo', 'Allie_Hess', 'Candace_Johnson', 'Jessica_Herrman', 'Taylor_Walker', 'Jasmine_Johnson', 'Jessica_Johnson', 'Lauren_Gaston', 'Madison_Lewis', 'Bryan_Blitz', 'Don_Trentham', 'Molly_Schneider', 'Kolby_Banker', 'Brittany_Boehm Jones', 'Sam_Lawson', 'Andrew_Paul', 'Dr. Mark_Adams']
# ['Kelsey_Dossey', 'Lauren_Selaiden', 'Payton_Goulding', 'Erin_Webb', 'Grace_Kitts', 'Anna_Frick', 'Kaitlyn_Clark', 'Rachel_Hignett', 'Bethany_Coons', 'Melanie_Donaldson', 'Lizzy_Akre', 'Rachel_Hise', 'Kristen_Rivers', 'Peyton_Joseph', 'Sarah_Luebbert', 'Natalie_McDonough', 'Savannah_Trujillo', 'Allie_Hess', 'Izzy_Coulter', 'Jasmine_Johnson', 'Jessica_Johnson', 'Lauren_Gaston', 'Erin_Jones', 'Madison_Lewis', 'Mercedes_Sapp', 'Bryan_Blitz', 'Don_Trentham', 'Molly_Schneider', 'John_Hawks', 'Kolby_Banker', 'Brittany_Boehm Jones', 'Jamila_St. Ann', 'Dr. Mark_Adams', 'Colleen_Imhoff', 'Kate_Lakin', 'Dawn_Malone', 'Jake_Schoch', 'Miranda_McKinsey']
# ['Peyton_Bauman', 'Kelsey_Dossey', 'Brynne_Polivka', 'Payton_Goulding', 'Bella_Alessi', 'Grace_Kitts', 'Anna_Frick', 'Kaitlyn_Clark', 'Cassidy_Nurnberger', 'Bethany_Coons', 'Zoe_Cross', 'Lindsey_Whitmore', 'Tess_Rellihan', 'Lizzy_Akre', 'Rachel_Hise', 'Kristen_Rivers', 'Peyton_Joseph', 'Sarah_Luebbert', 'Macy_Trujillo', 'Savannah_Trujillo', 'Allie_Hess', 'Izzy_Coulter', 'Morcquess_Oliphant', 'Jessica_Johnson', 'Lauren_Gaston', 'Madison_Lewis', 'Momola_Adesanmi', 'Mercedes_Sapp', 'Bryan_Blitz', 'Don_Trentham', 'Molly_Schneider', 'Amy_Edwards', 'John_Hawks', 'Kolby_Banker', 'Jamila_St. Ann', 'Dr. Mark_Adams', 'Colleen_Imhoff', 'Kate_Lakin', 'Dawn_Malone', 'Miranda_McKinsey']
# ['Peyton_Bauman', 'Kelsey_Dossey', 'Bella_Alessi', 'Grace_Kitts', 'Anna_Frick', 'Blythe_Beldner', 'Cassidy_Nurnberger', 'Bethany_Coons', 'Zoe_Cross', 'Lindsey_Whitmore', 'Keiarra_Slack', 'Rachel_Hise', 'Julissa_Cisneros', 'Peyton_Joseph', 'Sarah_Luebbert', 'Ariela_Beharry', 'Macy_Trujillo', 'Hailey_Blanchard', 'Skye_Kingsley', 'Izzy_Coulter', 'Morcquess_Oliphant', 'Lauren_Gaston', 'Madison_Lewis', 'Momola_Adesanmi', 'Mercedes_Sapp', 'Bryan_Blitz', 'Don_Trentham', 'Molly_Poletto', 'Kyle_Emerick', 'John_Hawks', 'Kolby_Banker', 'Jamila_St. Ann', 'Dr. Mark_Adams', 'Colleen_Imhoff', 'Dawn_Malone', 'Miranda_McKinsey']
# ['Peyton_Bauman', 'McKenna_Sheehan', 'Eryka_McIntyre', 'Jadyn_Easley', 'Bella_Alessi', 'Grace_Kitts', 'Anna_Frick', 'Blythe_Beldner', 'Cassidy_Nurnberger', 'Zoe_Cross', 'Lindsey_Whitmore', 'Janna_Singleton', 'Keiarra_Slack', 'Kyla_Johnson', 'Julissa_Cisneros', 'Peyton_Joseph', 'Sarah_Luebbert', 'Macy_Trujillo', 'Skye_Kingsley', 'Izzy_Coulter', 'Morgan_Davis', 'Morcquess_Oliphant', 'Haley_Steinke', 'Briana_Abam', 'Megan_Oduyoye', 'Madison_Lewis', 'Megan_Moll', 'Momola_Adesanmi', 'Caroline_Lyman', 'Gillian_Schulte', 'Bryan_Blitz', 'Don_Trentham', 'Molly_Poletto', 'Jordan_Quinlan', 'Brad_Leonard', 'Grace_Noteboom', 'Kyle_Emerick', 'Colleen_Imhoff', 'Dr. Mark_Adams', 'Dawn_Malone', 'Miranda_McKinsey', 'Jessica_Beckmann', 'Kelsea_Roth', 'Oliver_Blitz']
# ['Sophia_Worth', 'McKenna_Sheehan', 'Eryka_McIntyre', 'Jadyn_Easley', 'Bella_Alessi', 'Grace_Kitts', 'Kyra_Reeves', 'Blythe_Beldner', 'Cassidy_Nurnberger', 'Zoe_Cross', 'Lindsey_Whitmore', 'Keiarra_Slack', 'Kyla_Johnson', 'Julissa_Cisneros', 'Kloee_Grubb', 'Grace_Pettet', 'Hannah_Joella', 'Macy_Trujillo', 'Jenna_Bartels', 'Skye_Kingsley', 'Madilyn_Hamline', 'Morgan_Davis', 'Morcquess_Oliphant', 'Haley_Steinke', 'Megan_Oduyoye', 'Isabella_Alessio', 'Momola_Adesanmi', 'Caroline_Lyman', 'Stefanie_Golan', 'Andy_Stoots', 'Molly_Poletto', 'Brad_Leonard', 'Kyle_Emerick', 'Dr. Mark_Adams', 'Dawn_Malone', 'Miranda_McKinsey', 'Ryan_Imhoff', 'Abigail _Rogers']
# ['Sophia_Worth', 'McKenna_Sheehan', 'Eryka_McIntyre', 'Jadyn_Easley', 'Kylie_Dobbs', 'Jenna_McCormick', 'Kyra_Reeves', 'Blythe_Beldner', 'Cassidy_Nurnberger', 'Milena_Fischer', 'Avery_Brandt', 'Ashlyn_Mills', 'Leah_Selm', 'Kyla_Johnson', 'Julissa_Cisneros', 'Grace_Pettet', 'Hannah_Joella', 'Macy_Trujillo', 'Jenna_Bartels', 'Skye_Kingsley', 'Madilyn_Hamline', 'Morgan_Davis', 'Haley_Steinke', 'Gia_Woodfolk', 'Megan_Oduyoye', 'Isabella_Alessio', 'Momola_Adesanmi', 'Caroline_Lyman', 'Bella_Hollenbach', 'Stefanie_Golan', 'Andy_Stoots', 'Molly_Poletto', 'Dawn_Malone', 'Miranda_McKinsey', 'Abigail _Rogers']

# %%
name_df_test_miz
# Out:
#             1996_season          1997_season        1998_season  \
# 0         Heather_Arney          Nikki_Thole      Dyana_Russell
# 1            Amy_Haines      Amy _Timmermann        Nikki_Thole
# 2            Grace_Blum        Jennifer_Kram    Amy _Timmermann
# 3         Jennifer_Kram     Heather_Buchheit      Jennifer_Kram
# 4      Heather_Buchheit        Laura_McKenna       Sarah_Sallee
# 5          Erin_Cummins           Kate_Dwyer   Heather_Buchheit
# 6          Melissa_Bell         Mandy_Waters      Laura_McKenna
# 7            Kate_Dwyer       Andrea_Czarnik         Kate_Dwyer
# 8      Stephanie_Bodine     Jennifer_Maunder       Mandy_Waters
# 9        Andrea_Czarnik       Kristin_Boeker     Andrea_Czarnik
# 10        Sharon_Wirkus        Becky_Paulsen   Whitney_Blackmar
# 11        Jamie _Miller  Jennifer _O'Donnell   Jennifer_Maunder
# 12     Jennifer _Murphy           Robyn_Reeb     Kristin_Boeker
# 13        Robin_Neumann        Liz_Passanise      Becky_Paulsen
# 14  Jennifer _O'Donnell          Angela_Doss   Michelle_Hindman
# 15           Robyn_Reeb        Jackie_Adamec      Erin_Grimsley
# 16        Liz_Passanise     Elizabeth_LaTour      Liz_Passanise
# 17          Angela_Doss      Jessica_Graczyk    Shelly_DonMoyer
# 18         Sarah_Taylor          Erin_Waller  Stephanie_Brennan
# 19        Sarah_Whiting          Bryan_Blitz      Jackie_Adamec
# 20    Melissa_Grinstead                  NaN   Elizabeth_LaTour
# 21     Elizabeth_LaTour                  NaN      Graham_Watson
# 22      Jessica_Graczyk                  NaN    Jessica_Graczyk
# 23          Bryan_Blitz                  NaN        Bryan_Blitz
# 24                  NaN                  NaN                NaN
# 25                  NaN                  NaN                NaN
# 26                  NaN                  NaN                NaN
# 27                  NaN                  NaN                NaN
# 28                  NaN                  NaN                NaN
# 29                  NaN                  NaN                NaN
#
#           1999_season          2000_season          2001_season  \
# 0       Dyana_Russell        Dyana_Russell        Dyana_Russell
# 1         Nikki_Thole          Nikki_Thole      Carrie_Crossett
# 2     Amy _Timmermann      Amy _Timmermann          Dallas_Bird
# 3       Jennifer_Kram          Karen_Bauer          Karen_Bauer
# 4        Sarah_Sallee         Sarah_Sallee        Adriene_Davis
# 5    Heather_Buchheit        Adriene_Davis      Kristin_Gibbons
# 6         Amy_O'Leary      Kristin_Gibbons         Ashley_Gibbs
# 7          Kate_Dwyer      Amanda_Williams         Mandy_Waters
# 8        Mandy_Waters         Mandy_Waters     Colleen_Macarthy
# 9     Mandy_Pavlovits       Suzanne_Probst       Suzanne_Probst
# 10     Suzanne_Probst       Tamisha _Ellis         Kristin_Heil
# 11     Tamisha _Ellis       Kristin_Boeker           Lacy_Moore
# 12     Kristin_Boeker        Becky_Paulsen          Kim_Hibbert
# 13      Becky_Paulsen     Michelle_Hindman         Angela_Furin
# 14   Michelle_Hindman          Laura_Smith     Melissa _Peabody
# 15        Laura_Smith    Jennifer_McMaster     Melissa_McLellan
# 16      Erin_Grimsley       Kathleen_Wiley         Shea_Swoboda
# 17     Kathleen_Wiley     Melissa_McLellan    Stephanie_Brennan
# 18      Liz_Passanise      Shelly_DonMoyer        Tamara_Kochen
# 19    Shelly_DonMoyer    Stephanie_Brennan      Emma Kate_Young
# 20  Stephanie_Brennan         Megan_Duncan         Megan_Duncan
# 21      Jackie_Adamec        Graham_Watson  Stephanie _Krawczyk
# 22   Elizabeth_LaTour      Jessica_Graczyk          Bryan_Blitz
# 23      Graham_Watson        Carey _Patton                  NaN
# 24    Jessica_Graczyk  Stephanie _Krawczyk                  NaN
# 25        Bryan_Blitz          Bryan_Blitz                  NaN
# 26                NaN                  NaN                  NaN
# 27                NaN                  NaN                  NaN
# 28                NaN                  NaN                  NaN
# 29                NaN                  NaN                  NaN
#
#             2002_season          2003_season       2004_season  \
# 0       Carrie_Crossett           Kira_Reyes        Kira_Reyes
# 1         Breanah_Glynn         Mallory_Ames      Mallory_Ames
# 2           Karen_Bauer          Karen_Bauer      Beth_Wheeler
# 3         Adriene_Davis        Adriene_Davis       Karen_Bauer
# 4       Kristin_Gibbons      Kristin_Gibbons       Megan_Smith
# 5           Erica_Pusch          Erica_Pusch     Casey_Dreyfus
# 6          Ashley_Gibbs         Ashley_Gibbs        Jenna_Lind
# 7        Jennifer_Nobis       Jennifer_Nobis       Erica_Pusch
# 8       Amber_Swinehart      Amber_Swinehart      Ashley_Gibbs
# 9        Suzanne_Probst     Elyse_Nikonchuck    Jennifer_Nobis
# 10         Kristin_Heil         Kristin_Heil   Amber_Swinehart
# 11           Lacy_Moore           Lacy_Moore  Elyse_Nikonchuck
# 12          Kim_Hibbert          Kim_Hibbert      Kristin_Heil
# 13         Angela_Furin       Melissa_Griggs        Lacy_Moore
# 14     Melissa _Peabody     Melissa _Peabody     Laura_Buehrig
# 15         Kylie_Wilson          Aria_Hudetz  Melissa _Peabody
# 16     Melissa_McLellan     Melissa_McLellan       Aria_Hudetz
# 17         Shea_Swoboda         Shea_Swoboda   Maddie_Senkosky
# 18        Kylie_Moorman        Margaret_Malm      Shea_Swoboda
# 19        Tamara_Kochen         Lauren_Grice      Lauren_Grice
# 20      Emma Kate_Young         Megan_Duncan     Margaret_Malm
# 21         Megan_Duncan  Stephanie _Krawczyk   Lauren_Vineyard
# 22  Stephanie _Krawczyk          Bryan_Blitz       Bryan_Blitz
# 23          Bryan_Blitz                  NaN               NaN
# 24                  NaN                  NaN               NaN
# 25                  NaN                  NaN               NaN
# 26                  NaN                  NaN               NaN
# 27                  NaN                  NaN               NaN
# 28                  NaN                  NaN               NaN
# 29                  NaN                  NaN               NaN
#
#          2005_season  ...           2012_season           2013_season  \
# 0         Kira_Reyes  ...    McKenzie_Sauerwein    McKenzie_Sauerwein
# 1       Mallory_Ames  ...  Dominique_Richardson  Dominique_Richardson
# 2    Meghan_Pfeiffer  ...       Brooke_Williams       Brooke_Williams
# 3      Lindsay_McCoy  ...          Haley_Krentz             Erin_Webb
# 4        Anne_Baxter  ...       Brittany_Conley       Brittany_Conley
# 5      Casey_Dreyfus  ...        Reagan_Russell        Reagan_Russell
# 6        Erica_Pusch  ...      Taiwo_Adeshigbin   Danielle_Nottingham
# 7       Beth_Warwick  ...   Danielle_Nottingham          Kaysie_Clark
# 8     Jennifer_Nobis  ...          Kaysie_Clark     Melanie_Donaldson
# 9    Amber_Swinehart  ...          Lauren_Flynn          Lauren_Flynn
# 10  Elyse_Nikonchuck  ...       Macee_Blanchard       Macee_Blanchard
# 11        Mo_Redmond  ...           Sarah_Thune           Sarah_Thune
# 12    Janelle_Cordia  ...          Alyssa_Diggs          Alyssa_Diggs
# 13     Caroline_Pohl  ...            Allison_Hu        Kristen_Rivers
# 14     Laura_Buehrig  ...             Kaz_James             Kaz_James
# 15       Aria_Hudetz  ...      Loudell_Crumpler          Taylor_Grant
# 16   Maddie_Senkosky  ...          Taylor_Grant        Rachel_Hignett
# 17          Kat_Tarr  ...         Jessica_Greer       Candace_Johnson
# 18    Ashley_Hamblin  ...        Kelsey_Mulcahy       Jessica_Herrman
# 19      Lauren_Grice  ...            Abi_Raymer       Lauren_Selaiden
# 20     Margaret_Malm  ...       Candace_Johnson       Jasmine_Johnson
# 21     Mallory_Frost  ...       Jessica_Herrman      Brittanee_Randle
# 22   Lauren_Vineyard  ...     Shelby_Sonnefeldt           Bryan_Blitz
# 23    Annie_Meredith  ...      Brittanee_Randle                   NaN
# 24       Bryan_Blitz  ...           Bryan_Blitz                   NaN
# 25               NaN  ...                   NaN                   NaN
# 26               NaN  ...                   NaN                   NaN
# 27               NaN  ...                   NaN                   NaN
# 28               NaN  ...                   NaN                   NaN
# 29               NaN  ...                   NaN                   NaN
#
#            2014_season        2015_season        2016_season  \
# 0   McKenzie_Sauerwein      Kelsey_Dossey      Kelsey_Dossey
# 1      Lauren_Selaiden    Lauren_Selaiden    Lauren_Selaiden
# 2            Erin_Webb    Payton_Goulding    Payton_Goulding
# 3      Brittany_Conley          Erin_Webb          Erin_Webb
# 4       Reagan_Russell    Brittany_Conley        Grace_Kitts
# 5        Kaitlyn_Clark     Reagan_Russell         Anna_Frick
# 6       Rachel_Hignett      Kaitlyn_Clark      Kaitlyn_Clark
# 7         Kaysie_Clark     Rachel_Hignett     Rachel_Hignett
# 8    Melanie_Donaldson      Bethany_Coons      Bethany_Coons
# 9         Lauren_Flynn  Melanie_Donaldson  Melanie_Donaldson
# 10     Macee_Blanchard       Lauren_Flynn         Lizzy_Akre
# 11          Lizzy_Akre    Macee_Blanchard        Rachel_Hise
# 12      Kristen_Rivers         Lizzy_Akre     Kristen_Rivers
# 13           Kaz_James        Rachel_Hise      Peyton_Joseph
# 14      Alli_Magaletta     Kristen_Rivers     Sarah_Luebbert
# 15        Taylor_Grant     Alli_Magaletta  Natalie_McDonough
# 16   Savannah_Trujillo        Amanda_Shaw  Savannah_Trujillo
# 17          Allie_Hess  Natalie_McDonough         Allie_Hess
# 18     Candace_Johnson  Savannah_Trujillo       Izzy_Coulter
# 19     Jessica_Herrman         Allie_Hess    Jasmine_Johnson
# 20       Taylor_Walker    Candace_Johnson    Jessica_Johnson
# 21     Jasmine_Johnson    Jessica_Herrman      Lauren_Gaston
# 22     Jessica_Johnson      Taylor_Walker         Erin_Jones
# 23       Lauren_Gaston    Jasmine_Johnson      Madison_Lewis
# 24    Brittanee_Randle    Jessica_Johnson      Mercedes_Sapp
# 25         Bryan_Blitz      Lauren_Gaston        Bryan_Blitz
# 26                 NaN      Madison_Lewis       Don_Trentham
# 27                 NaN        Bryan_Blitz    Molly_Schneider
# 28                 NaN       Don_Trentham         John_Hawks
# 29                 NaN    Molly_Schneider       Kolby_Banker
#
#            2017_season         2018_season         2019_season  \
# 0        Peyton_Bauman       Peyton_Bauman       Peyton_Bauman
# 1        Kelsey_Dossey       Kelsey_Dossey     McKenna_Sheehan
# 2       Brynne_Polivka        Bella_Alessi      Eryka_McIntyre
# 3      Payton_Goulding         Grace_Kitts        Jadyn_Easley
# 4         Bella_Alessi          Anna_Frick        Bella_Alessi
# 5          Grace_Kitts      Blythe_Beldner         Grace_Kitts
# 6           Anna_Frick  Cassidy_Nurnberger          Anna_Frick
# 7        Kaitlyn_Clark       Bethany_Coons      Blythe_Beldner
# 8   Cassidy_Nurnberger           Zoe_Cross  Cassidy_Nurnberger
# 9        Bethany_Coons    Lindsey_Whitmore           Zoe_Cross
# 10           Zoe_Cross       Keiarra_Slack    Lindsey_Whitmore
# 11    Lindsey_Whitmore         Rachel_Hise     Janna_Singleton
# 12       Tess_Rellihan    Julissa_Cisneros       Keiarra_Slack
# 13          Lizzy_Akre       Peyton_Joseph        Kyla_Johnson
# 14         Rachel_Hise      Sarah_Luebbert    Julissa_Cisneros
# 15      Kristen_Rivers      Ariela_Beharry       Peyton_Joseph
# 16       Peyton_Joseph       Macy_Trujillo      Sarah_Luebbert
# 17      Sarah_Luebbert    Hailey_Blanchard       Macy_Trujillo
# 18       Macy_Trujillo       Skye_Kingsley       Skye_Kingsley
# 19   Savannah_Trujillo        Izzy_Coulter        Izzy_Coulter
# 20          Allie_Hess  Morcquess_Oliphant        Morgan_Davis
# 21        Izzy_Coulter       Lauren_Gaston  Morcquess_Oliphant
# 22  Morcquess_Oliphant       Madison_Lewis       Haley_Steinke
# 23     Jessica_Johnson     Momola_Adesanmi         Briana_Abam
# 24       Lauren_Gaston       Mercedes_Sapp       Megan_Oduyoye
# 25       Madison_Lewis         Bryan_Blitz       Madison_Lewis
# 26     Momola_Adesanmi        Don_Trentham          Megan_Moll
# 27       Mercedes_Sapp       Molly_Poletto     Momola_Adesanmi
# 28         Bryan_Blitz        Kyle_Emerick      Caroline_Lyman
# 29        Don_Trentham          John_Hawks     Gillian_Schulte
#
#            2020_season         2021_season
# 0         Sophia_Worth        Sophia_Worth
# 1      McKenna_Sheehan     McKenna_Sheehan
# 2       Eryka_McIntyre      Eryka_McIntyre
# 3         Jadyn_Easley        Jadyn_Easley
# 4         Bella_Alessi         Kylie_Dobbs
# 5          Grace_Kitts     Jenna_McCormick
# 6          Kyra_Reeves         Kyra_Reeves
# 7       Blythe_Beldner      Blythe_Beldner
# 8   Cassidy_Nurnberger  Cassidy_Nurnberger
# 9            Zoe_Cross      Milena_Fischer
# 10    Lindsey_Whitmore        Avery_Brandt
# 11       Keiarra_Slack        Ashlyn_Mills
# 12        Kyla_Johnson           Leah_Selm
# 13    Julissa_Cisneros        Kyla_Johnson
# 14         Kloee_Grubb    Julissa_Cisneros
# 15        Grace_Pettet        Grace_Pettet
# 16       Hannah_Joella       Hannah_Joella
# 17       Macy_Trujillo       Macy_Trujillo
# 18       Jenna_Bartels       Jenna_Bartels
# 19       Skye_Kingsley       Skye_Kingsley
# 20     Madilyn_Hamline     Madilyn_Hamline
# 21        Morgan_Davis        Morgan_Davis
# 22  Morcquess_Oliphant       Haley_Steinke
# 23       Haley_Steinke        Gia_Woodfolk
# 24       Megan_Oduyoye       Megan_Oduyoye
# 25    Isabella_Alessio    Isabella_Alessio
# 26     Momola_Adesanmi     Momola_Adesanmi
# 27      Caroline_Lyman      Caroline_Lyman
# 28      Stefanie_Golan    Bella_Hollenbach
# 29         Andy_Stoots      Stefanie_Golan
#
# [30 rows x 26 columns]

# %%
name_df_test_minn['returner'] = name_df_test_miz['2013_season'].isin(name_df_test_miz['2012_season'])
name_df_test_minn['returner'].sum()
# Out:
# 20

# %% [markdown]
# ### Minnesota table

# %%
years = ['2012','2013','2014','2015','2016','2017','2018','2019','2020-21']

# %%
base_url = 'https://gophersports.com/sports/womens-soccer/roster/'
urls = []
for year in years:
    url_test = base_url+year
    urls.append(url_test)

# %%
print(urls)
# Out:
# ['https://gophersports.com/sports/womens-soccer/roster/2012', 'https://gophersports.com/sports/womens-soccer/roster/2013', 'https://gophersports.com/sports/womens-soccer/roster/2014', 'https://gophersports.com/sports/womens-soccer/roster/2015', 'https://gophersports.com/sports/womens-soccer/roster/2016', 'https://gophersports.com/sports/womens-soccer/roster/2017', 'https://gophersports.com/sports/womens-soccer/roster/2018', 'https://gophersports.com/sports/womens-soccer/roster/2019', 'https://gophersports.com/sports/womens-soccer/roster/2020-21']

# %%
name_df_test_minn = pd.DataFrame(index = range(0,26))
for url_test in urls:
    # empty year list
    raw_list_test = []
    
    # Set up parser
    page_test = urlopen(url_test)
    html_test = page_test.read().decode('utf-8')
    soup_test = BeautifulSoup(html_test,"html.parser")
    
    # Get last names
    names_test = soup_test.find_all('a',{'class':"sidearm-roster-player-name"})

    year_test_pull = soup_test.find('title')
    year_test = year_test_pull.text[3:7]
    for name_test in names_test:
        raw_list_test.append(name_test.text)
        
    year_list_test = []
    for year_item_test in raw_list_test:
        year_item_test_strip = year_item_test.strip()
        year_list_test.append(year_item_test_strip.replace('\n',"_"))
    print(year_list_test)
    name_df_test_minn[year_test+'_season'] = pd.Series(year_list_test)
# Out:
# ['Kristen_Knutson', 'Cat_Parkhill', 'Nicole_Baier', 'Taylor_Uhl', 'Brianne_Price', 'Haley_Helverson', 'Katie_Thyken', 'Allie_Phillips', 'Ellie_Arvesen', 'Elle_Dykema', 'Marissa_Price', 'Steph_Brandt', 'Olivia_Bagnall', 'Tamara_Strahota', 'Becca_Roberts', 'Allie_Reinke', 'Lauren_Bauer', 'MacKenzie_Misel', 'Taylor_Wodnick', 'Jackie_Voigt']
# ['Kristen_Knutson', 'Tarah_Hobbs', 'Mara_Dougherty', 'Simone_Kolander', 'Olivia_Schultz', 'Haley_Helverson', 'Katie_Thyken', 'Allie_Giddings', 'Ellie_Arvesen', 'Erin_Booth', 'Elle_Dykema', 'Josee_Stiever', 'Steph_Brandt', 'Jen_Larrick', 'Taylor_Stainbrook', 'Rashida_Beal', 'Ashley_Pafko', 'Becca_Roberts', 'Allie_Reinke', 'Lauren_Bauer', 'MacKenzie_Misel', 'Vanessa_Johnston', 'Taylor_Wodnick']
# ['Kirsti_Lilja', 'Tarah_Hobbs', 'Mara_Dougherty', 'Simone_Kolander', 'Kellie_McGahn', 'Olivia_Schultz', 'Haley_Helverson', 'Katie_Thyken', 'Sydney_Squires', 'Ellie_Arvesen', 'Erin_Booth', 'Josee_Stiever', 'Hannah_Holm', 'Taylor_Stainbrook', 'Jen_Larrick', 'Maddie_Gaffney', 'Rachel_McCloskey', 'Rashida_Beal', 'Ashley_Pafko', 'Becca_Roberts', 'Allie_Reinke', 'Tori_Burnett', 'Julianna_Gernes', 'Alyssa_Blahnik', 'Megan_Koenig', 'Taylor_Wodnick', 'Stefanie_Golan', 'Deana_Waintraub Stafford', 'Elle_Dykema', 'MacKenzie_Misel', 'Mary Jo_Brandt', 'Tam_Warnke']
# ['Kirsti_Lilja', 'Tarah_Hobbs', 'Mara_Dougherty', 'Simone_Kolander', 'Kellie_McGahn', 'Emily_Peterson', 'Haley_Helverson', 'Molly_Fiedler', 'Sydney_Squires', 'Ellie_Arvesen', 'Maddie_Castro', 'Emily_Heslin', 'Josee_Stiever', 'Hugrun_Fridriksdottir', 'Taylor_Stainbrook', 'Jen_Larrick', 'Maddie_Gaffney', 'Rachel_McCloskey', 'Rashida_Beal', 'Ashley_Pafko', 'April_Bockin', 'Allie_Reinke', 'Tori_Burnett', 'Julianna_Gernes', 'Megan_Koenig', 'Kailee_Sharp', 'Stefanie_Golan', 'Andy_Stoots', 'Tam_Warnke', 'Natasha_Bell', 'Elle_Dykema', 'Mary Jo_Brandt']
# ['Tarah_Hobbs', 'Mara_Dougherty', 'Simone_Kolander', 'Kellie_McGahn', 'Emily_Peterson', 'TJ_McKendrick', 'Molly_Fiedler', 'Sydney_Squires', 'Catherine_Billings', 'Maddie_Castro', 'Emily_Heslin', 'Josee_Stiever', 'Hugrun_Fridriksdottir', 'Nikki_Albrecht', 'Cherry_Fast', 'Maddie_Gaffney', 'Maya_Rajacich', 'Rashida_Beal', 'Ashley_Pafko', 'April_Bockin', 'Haley_Mennes', 'Tori_Burnett', 'Julianna_Gernes', 'Marisa_Windingstad', 'Megan_Koenig', 'Kailee_Sharp', 'Stefanie_Golan', 'Andy_Stoots', 'Sara_Johnson', 'Kari_Ornes', 'Natasha_Bell', 'Mary Jo_Brandt']
# ['Maddie_Nielsen', 'Makenzie_Langdok', 'Kellie_McGahn', 'Emily_Peterson', 'TJ_McKendrick', 'Molly_Fiedler', 'Sydney_Squires', 'Catherine_Billings', 'Maddie_Castro', 'Emily_Heslin', 'Arianna_Del Moral', 'Nikki_Albrecht', 'Maddie_Gaffney', 'Celina_Nummerdor', 'Athena_Kuehn', 'April_Bockin', 'Haley_Mennes', 'Tori_Burnett', 'Julianna_Gernes', 'Marisa_Windingstad', 'Megan_Koenig', 'Haley_Hartkemeyer', 'Stefanie_Golan', 'Brad_Swenby', 'Sara_Johnson', 'Kari_Ornes', 'Hugrun_Fridriksdottir', 'Mary Jo_Brandt', 'Becky_Maines']
# ['Ana_Aguado', 'Maddie_Nielsen', 'Makenzie_Langdok', 'Delaney_Stekr', 'Emily_Peterson', 'TJ_McKendrick', 'Molly_Fiedler', 'Patricia_Ward', 'Catherine_Billings', 'Maddie_Castro', 'Emily_Heslin', 'Arianna_Del Moral', 'Nikki_Albrecht', 'McKenna_Buisman', 'Megan_Gray', 'Celina_Nummerdor', 'Athena_Kuehn', 'April_Bockin', 'Haley_Mennes', 'Alana_Dressely', 'Emily_Bunnell', 'Marisa_Windingstad', 'Haley_Hartkemeyer', 'Stefanie_Golan', 'Becky_Maines', 'Molly_Rouse', 'Alli_Lipsher', 'Sara_Johnson', 'Hugrun_Fridriksdottir', 'Mary Jo_Brandt']
# ['Ana_Aguado', 'Maddie_Nielsen', 'Makenzie_Langdok', 'Delaney_Stekr', 'Lauren _Roberts', 'TJ_McKendrick', 'Patricia_Ward', 'Catherine_Billings', 'Katie _Duong', 'Arianna_Del Moral', 'Keziah_Inniss', 'Nikki_Albrecht', 'Eva_Bruer', 'McKenna_Buisman', 'Megan_Gray', 'Celina_Nummerdor', 'Athena_Kuehn', 'Paige_Elliott', 'Alana_Dressely', 'Marisa_Windingstad', 'Haley_Hartkemeyer', 'Megan _Plaschko', 'Sadie _Harper', 'Katie_Koker', 'Stefanie_Golan', 'Becky_Maines', 'Alli_Lipsher', 'Sara_Johnson', 'Mary Jo_Brandt']
# ['Ana_Aguado', 'Maddie_Nielsen', 'Makenzie_Langdok', 'Delaney_Stekr', 'Maddie_Baker', 'Patricia_Ward', 'Sophia_Boman', 'Katie _Duong', 'Arianna_Del Moral', 'Keziah_Inniss', 'Abi_Frandsen', 'Eva_Bruer', 'McKenna_Buisman', 'Megan_Gray', 'Celina_Nummerdor', 'Athena_Kuehn', 'Paige_Elliott', 'Alana_Dressely', 'Josie_Wood', 'Megan _Plaschko', 'Sadie _Harper', 'Izzy_Brown', 'Katie_Koker', 'Lauren_Donovan', 'Becky_Maines', 'Maya_Hayes', 'Tarah_Nupson', 'Lauren_Roberts', 'Sara_Johnson']

# %%
name_df_test_minn
# Out:
#         2012_season        2013_season        2014_season  \
# 0   Kristen_Knutson    Kristen_Knutson       Kirsti_Lilja
# 1      Cat_Parkhill        Tarah_Hobbs        Tarah_Hobbs
# 2      Nicole_Baier     Mara_Dougherty     Mara_Dougherty
# 3        Taylor_Uhl    Simone_Kolander    Simone_Kolander
# 4     Brianne_Price     Olivia_Schultz      Kellie_McGahn
# 5   Haley_Helverson    Haley_Helverson     Olivia_Schultz
# 6      Katie_Thyken       Katie_Thyken    Haley_Helverson
# 7    Allie_Phillips     Allie_Giddings       Katie_Thyken
# 8     Ellie_Arvesen      Ellie_Arvesen     Sydney_Squires
# 9       Elle_Dykema         Erin_Booth      Ellie_Arvesen
# 10    Marissa_Price        Elle_Dykema         Erin_Booth
# 11     Steph_Brandt      Josee_Stiever      Josee_Stiever
# 12   Olivia_Bagnall       Steph_Brandt        Hannah_Holm
# 13  Tamara_Strahota        Jen_Larrick  Taylor_Stainbrook
# 14    Becca_Roberts  Taylor_Stainbrook        Jen_Larrick
# 15     Allie_Reinke       Rashida_Beal     Maddie_Gaffney
# 16     Lauren_Bauer       Ashley_Pafko   Rachel_McCloskey
# 17  MacKenzie_Misel      Becca_Roberts       Rashida_Beal
# 18   Taylor_Wodnick       Allie_Reinke       Ashley_Pafko
# 19     Jackie_Voigt       Lauren_Bauer      Becca_Roberts
# 20              NaN    MacKenzie_Misel       Allie_Reinke
# 21              NaN   Vanessa_Johnston       Tori_Burnett
# 22              NaN     Taylor_Wodnick    Julianna_Gernes
# 23              NaN                NaN     Alyssa_Blahnik
# 24              NaN                NaN       Megan_Koenig
# 25              NaN                NaN     Taylor_Wodnick
#
#               2015_season            2016_season         2017_season  \
# 0            Kirsti_Lilja            Tarah_Hobbs      Maddie_Nielsen
# 1             Tarah_Hobbs         Mara_Dougherty    Makenzie_Langdok
# 2          Mara_Dougherty        Simone_Kolander       Kellie_McGahn
# 3         Simone_Kolander          Kellie_McGahn      Emily_Peterson
# 4           Kellie_McGahn         Emily_Peterson       TJ_McKendrick
# 5          Emily_Peterson          TJ_McKendrick       Molly_Fiedler
# 6         Haley_Helverson          Molly_Fiedler      Sydney_Squires
# 7           Molly_Fiedler         Sydney_Squires  Catherine_Billings
# 8          Sydney_Squires     Catherine_Billings       Maddie_Castro
# 9           Ellie_Arvesen          Maddie_Castro        Emily_Heslin
# 10          Maddie_Castro           Emily_Heslin   Arianna_Del Moral
# 11           Emily_Heslin          Josee_Stiever      Nikki_Albrecht
# 12          Josee_Stiever  Hugrun_Fridriksdottir      Maddie_Gaffney
# 13  Hugrun_Fridriksdottir         Nikki_Albrecht    Celina_Nummerdor
# 14      Taylor_Stainbrook            Cherry_Fast        Athena_Kuehn
# 15            Jen_Larrick         Maddie_Gaffney        April_Bockin
# 16         Maddie_Gaffney          Maya_Rajacich        Haley_Mennes
# 17       Rachel_McCloskey           Rashida_Beal        Tori_Burnett
# 18           Rashida_Beal           Ashley_Pafko     Julianna_Gernes
# 19           Ashley_Pafko           April_Bockin  Marisa_Windingstad
# 20           April_Bockin           Haley_Mennes        Megan_Koenig
# 21           Allie_Reinke           Tori_Burnett   Haley_Hartkemeyer
# 22           Tori_Burnett        Julianna_Gernes      Stefanie_Golan
# 23        Julianna_Gernes     Marisa_Windingstad         Brad_Swenby
# 24           Megan_Koenig           Megan_Koenig        Sara_Johnson
# 25           Kailee_Sharp           Kailee_Sharp          Kari_Ornes
#
#            2018_season         2019_season        2020_season
# 0           Ana_Aguado          Ana_Aguado         Ana_Aguado
# 1       Maddie_Nielsen      Maddie_Nielsen     Maddie_Nielsen
# 2     Makenzie_Langdok    Makenzie_Langdok   Makenzie_Langdok
# 3        Delaney_Stekr       Delaney_Stekr      Delaney_Stekr
# 4       Emily_Peterson     Lauren _Roberts       Maddie_Baker
# 5        TJ_McKendrick       TJ_McKendrick      Patricia_Ward
# 6        Molly_Fiedler       Patricia_Ward       Sophia_Boman
# 7        Patricia_Ward  Catherine_Billings       Katie _Duong
# 8   Catherine_Billings        Katie _Duong  Arianna_Del Moral
# 9        Maddie_Castro   Arianna_Del Moral      Keziah_Inniss
# 10        Emily_Heslin       Keziah_Inniss       Abi_Frandsen
# 11   Arianna_Del Moral      Nikki_Albrecht          Eva_Bruer
# 12      Nikki_Albrecht           Eva_Bruer    McKenna_Buisman
# 13     McKenna_Buisman     McKenna_Buisman         Megan_Gray
# 14          Megan_Gray          Megan_Gray   Celina_Nummerdor
# 15    Celina_Nummerdor    Celina_Nummerdor       Athena_Kuehn
# 16        Athena_Kuehn        Athena_Kuehn      Paige_Elliott
# 17        April_Bockin       Paige_Elliott     Alana_Dressely
# 18        Haley_Mennes      Alana_Dressely         Josie_Wood
# 19      Alana_Dressely  Marisa_Windingstad    Megan _Plaschko
# 20       Emily_Bunnell   Haley_Hartkemeyer      Sadie _Harper
# 21  Marisa_Windingstad     Megan _Plaschko         Izzy_Brown
# 22   Haley_Hartkemeyer       Sadie _Harper        Katie_Koker
# 23      Stefanie_Golan         Katie_Koker     Lauren_Donovan
# 24        Becky_Maines      Stefanie_Golan       Becky_Maines
# 25         Molly_Rouse        Becky_Maines         Maya_Hayes

# %%
name_df_test_minn['returner'] = name_df_test_minn['2014_season'].isin(name_df_test_minn['2013_season'])
name_df_test_minn['returner'].sum()
# Out:
# 16

# %% [markdown]
# ## Nebraska roster scrape

# %%
from urllib.request import urlopen

# %%
from bs4 import BeautifulSoup

# %%
url = 'https://huskers.com/sports/womens-soccer/roster/2021'

# %%
page = urlopen(url)
html = page.read().decode('utf-8')
soup = BeautifulSoup(html, "html.parser")

# %%
nebraska_roster_21 = pd.DataFrame()

# %%
last_names = soup.find_all('span',{'class':"sidearm-roster-player-last-name"})
first_names = soup.find_all('span',{'class':"sidearm-roster-player-first-name"})
player_classes = soup.find_all('span',{'class':"sidearm-roster-player-academic-year"})

# %%
lname_list = []
for last_name in last_names:
    lname_list.append(last_name.text)
    
fname_list = []
for first_name in first_names:
    fname_list.append(first_name.text)
    
class_list = []
for player_class in player_classes:
    class_list.append(player_class.text)

# %%
class_list = class_list[70:]
lname_list = lname_list[:35]
fname_list = fname_list[:35]

# %%
len(class_list)
# Out:
# 35

# %%
nebraska_roster_21['last_name'] = lname_list
nebraska_roster_21['first_name'] = fname_list
nebraska_roster_21['class'] = class_list

# %%
nebraska_roster_21['class'].value_counts(normalize=True)
# Out:
# Fr.    0.314286
# Sr.    0.314286
# So.    0.257143
# Jr.    0.114286
# Name: class, dtype: float64

# %%
20/35
# Out:
# 0.5714285714285714

# %% [markdown]
# ### Mizzou Schedule Scrape

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

# %%
years = []
for year in range(2010,2022):
    years.append(str(year))

# %%
base_schedule_url = 'https://mutigers.com/sports/womens-soccer/schedule/'
schedule_urls = []
for year in years:
    miz_schedule_url = base_schedule_url+year
    schedule_urls.append(miz_schedule_url)

# %%
print(schedule_urls)
# Out:
# ['https://mutigers.com/sports/womens-soccer/schedule/2010', 'https://mutigers.com/sports/womens-soccer/schedule/2011', 'https://mutigers.com/sports/womens-soccer/schedule/2012', 'https://mutigers.com/sports/womens-soccer/schedule/2013', 'https://mutigers.com/sports/womens-soccer/schedule/2014', 'https://mutigers.com/sports/womens-soccer/schedule/2015', 'https://mutigers.com/sports/womens-soccer/schedule/2016', 'https://mutigers.com/sports/womens-soccer/schedule/2017', 'https://mutigers.com/sports/womens-soccer/schedule/2018', 'https://mutigers.com/sports/womens-soccer/schedule/2019', 'https://mutigers.com/sports/womens-soccer/schedule/2020', 'https://mutigers.com/sports/womens-soccer/schedule/2021']

# %%
miz_hist_schedule = pd.DataFrame()
opponent_list = []
date_list = []
result_list = []    
year_list = []
for schedule_url in schedule_urls:
    # empty lists

    
    # Set up parser
    page = urlopen(schedule_url)
    html = page.read().decode('utf-8')
    soup = BeautifulSoup(html,"html.parser")
    
    # pull info
    otags = soup.find_all('div',{"class":'sidearm-schedule-game-opponent-name'})
    dtags = soup.find_all('div',{"class":'sidearm-schedule-game-opponent-date'})
    rtags = soup.find_all('div',{'class':'sidearm-schedule-game-result'})
    
    # get result tag
    for rtag in rtags:
        game_result = rtag.find('span')
        if game_result:
            game_results = rtag.text
            
            #store names
            result_list.append(game_results.strip().replace('\n'," "))
            print(game_results.strip().replace('\n'," ")+", year: "+schedule_url[-4:])
            
    # get opponent tag
    for otag in otags:
        opponent_name = otag.find('a')
        if opponent_name:
            opponent_names = otag.text
            
            # store names
            opponent_list.append(opponent_names.strip().replace("\n"," "))
            
            # print(opponent_names.strip())
        year_list.append(schedule_url[-4:])
    # get date tag
    for dtag in dtags:
        game_date = dtag.find('span')
        if game_date:
            game_dates = dtag.text
            
            # store names
            date_list.append(game_dates.strip().replace("\n"," "))
            # print(game_dates.strip())
# Out:
# T, 2-2, year: 2010
# Canceled, year: 2010
# L, 3-2, year: 2010
# L, 3-1, year: 2010
# L, 6-1, year: 2010
# T, 1-1 2OT, year: 2010
# T, 1-1, year: 2010
# W, 4-0, year: 2010
# W, 3-2 2OT, year: 2010
# L, 3-2, year: 2010
# W, 4-1, year: 2010
# L, 3-1, year: 2010
# W, 2-1, year: 2010
# W, 1-0, year: 2010
# L, 4-2, year: 2010
# L, 1-0, year: 2010
# L, 4-2, year: 2010
# W, 2-0, year: 2010
# W, 5-2, year: 2010
# L, 5-0, year: 2010
# L, 4-1, year: 2010
# T, 1-1, year: 2011
# L, 2-1, year: 2011
# W, 4-1, year: 2011
# W, 1-0, year: 2011
# W, 4-2, year: 2011
# W, 3-0, year: 2011
# W, 2-0, year: 2011
# W, 1-0, year: 2011
# W, 1-0, year: 2011
# L, 2-0, year: 2011
# W, 3-0, year: 2011
# L, 1-0, year: 2011
# L, 2-0, year: 2011
# W, 1-0, year: 2011
# L, 2-1, year: 2011
# W, 4-0, year: 2011
# L, 3-1, year: 2011
# W, 5-2, year: 2011
# W, 3-2, year: 2011
# L, 1-0, year: 2011
# T, 2-2 4-3 PKs, year: 2011
# L, 3-0, year: 2011
# , year: 2012
# W, 5-1, year: 2012
# W, 2-0, year: 2012
# W, 3-2, year: 2012
# W, 4-1, year: 2012
# W, 2-0, year: 2012
# L, 1-0 OT, year: 2012
# W, 2-0, year: 2012
# W, 1-0, year: 2012
# W, 2-1, year: 2012
# W, 2-0, year: 2012
# W, 2-1, year: 2012
# L, 1-0, year: 2012
# W, 2-1 OT, year: 2012
# W, 2-0, year: 2012
# L, 2-1, year: 2012
# W, 2-1, year: 2012
# L, 2-1, year: 2012
# L, 3-1, year: 2012
# L, 2-1 OT, year: 2012
# W, 2-1, year: 2012
# L, 3-0, year: 2012
# T, 1-1 0-3 SO, year: 2012
# W, 3-2, year: 2013
# W, 5-1, year: 2013
# L, 2-1 OT, year: 2013
# W, 4-0, year: 2013
# W, 3-0, year: 2013
# L, 2-1, year: 2013
# L, 2-1 OT, year: 2013
# W, 3-0, year: 2013
# L, 3-2, year: 2013
# W, 3-1, year: 2013
# L, 1-0, year: 2013
# W, 1-0, year: 2013
# T, 1-1 2OT, year: 2013
# L, 2-1, year: 2013
# L, 1-0, year: 2013
# W, 2-1, year: 2013
# T, 1-1 2OT, year: 2013
# W, 2-1 2OT, year: 2013
# T, 1-1 2OT, year: 2013
# L, 2-1 OT, year: 2013
# L, 4-0, year: 2013
# W, 2-1, year: 2014
# T, 0-0 2OT, year: 2014
# L, 3-2, year: 2014
# W, 2-1 OT, year: 2014
# W, 3-1, year: 2014
# T, 0-0 2OT, year: 2014
# W, 1-0, year: 2014
# W, 4-3 2OT, year: 2014
# W, 3-1, year: 2014
# W, 3-1, year: 2014
# W, 1-0, year: 2014
# L, 3-1, year: 2014
# W, 2-1, year: 2014
# W, 2-0, year: 2014
# L, 3-2, year: 2014
# W, 2-0, year: 2014
# L, 1-0, year: 2014
# T, 3-3 2OT, year: 2014
# L, 3-0, year: 2014
# W, 2-1, year: 2014
# L, 2-1, year: 2014
# W, 3-1, year: 2014
# L, 1-0 OT, year: 2014
# T, 0-0, year: 2015
# T, 1-1, year: 2015
# W, 2-0, year: 2015
# T, 1-1 2OT, year: 2015
# L, 1-0, year: 2015
# W, 3-2 2OT, year: 2015
# T, 0-0 2OT, year: 2015
# T, 0-0, year: 2015
# W, 2-1, year: 2015
# L, 1-0, year: 2015
# L, 1-0, year: 2015
# W, 3-1, year: 2015
# T, 1-1, year: 2015
# W, 2-1, year: 2015
# L, 2-1, year: 2015
# W, 2-0, year: 2015
# W, 3-1, year: 2015
# W, 2-1 OT, year: 2015
# W, 1-0, year: 2015
# T, 1-1, year: 2015
# L, 2-1, year: 2015
# T, 1-1, year: 2016
# W, 3-2, year: 2016
# L, 2-1 OT, year: 2016
# W, 3-2 OT, year: 2016
# W, 2-1 OT, year: 2016
# W, 4-1, year: 2016
# L, 1-0, year: 2016
# W, 5-0, year: 2016
# L, 2-0, year: 2016
# W, 3-1, year: 2016
# W, 2-0, year: 2016
# W, 2-1 OT, year: 2016
# L, 1-0, year: 2016
# T, 1-1 2OT, year: 2016
# W, 2-0, year: 2016
# W, 2-1, year: 2016
# L, 1-0, year: 2016
# W, 4-3, year: 2016
# L, 1-0, year: 2016
# T, 3-3 7-8 PK, year: 2016
# L, 1-0 2OT, year: 2016
# L, 1-0, year: 2017
# W, 3-1, year: 2017
# W, 2-0, year: 2017
# T, 0-0, year: 2017
# L, 3-0, year: 2017
# L, 2-0, year: 2017
# L, 2-1 (2OT), year: 2017
# L, 2-1, year: 2017
# W, 2-1, year: 2017
# W, 3-1, year: 2017
# W, 3-0, year: 2017
# L, 3-1, year: 2017
# L, 5-1, year: 2017
# L, 5-3, year: 2017
# L, 2-1, year: 2017
# L, 3-2 (OT), year: 2017
# W, 2-1, year: 2017
# L, 2-0, year: 2017
# L, 3-2 OT, year: 2017
# W, 2-0, year: 2017
# W, 3-1, year: 2017
# L, 7-1, year: 2017
# W, 6-0, year: 2018
# W, 2-1, year: 2018
# T, 0-0 (2OT), year: 2018
# W, 2-1 (2OT), year: 2018
# L, 6-0, year: 2018
# L, 1-0 (OT), year: 2018
# L, 1-0 (OT), year: 2018
# L, 2-0, year: 2018
# W, 2-0, year: 2018
# W, 1-0, year: 2018
# W, 2-1, year: 2018
# T, 0-0 (2OT), year: 2018
# L, 2-1, year: 2018
# L, 1-0, year: 2018
# W, 2-1, year: 2018
# L, 2-1, year: 2018
# L, 1-0, year: 2018
# L, 1-0, year: 2018
# W, 2-0, year: 2018
# L, 2-1 (OT), year: 2018
# L, 3-2 (2OT), year: 2018
# L, 7-0, year: 2019
# W, 3-1, year: 2019
# W, 1-0, year: 2019
# W, 3-1, year: 2019
# W, 2-1, year: 2019
# W, 3-2 (2OT), year: 2019
# W, 2-1, year: 2019
# L, 2-1, year: 2019
# L, 3-2, year: 2019
# W, 2-1 (OT), year: 2019
# T, 1-1 (2OT), year: 2019
# L, 3-2, year: 2019
# L, 5-1, year: 2019
# L, 1-0, year: 2019
# L, 2-1, year: 2019
# W, 2-0, year: 2019
# L, 2-1, year: 2019
# L, 2-1, year: 2019
# L, 5-3, year: 2019
# L, 4-2, year: 2019
# L, 4-1, year: 2020
# W, 2-1, year: 2020
# L, 2-1, year: 2020
# T, 1-1 (2OT), year: 2020
# T, 1-1 (2OT), year: 2020
# W, 4-1, year: 2020
# Canceled, year: 2020
# W, 5-2, year: 2020
# W, 2-1, year: 2020
# L, 3-2, year: 2020
# W, 1-0, year: 2020
# L, 3-0, year: 2020
# L, 2-0, year: 2020
# T, 3-3 (2OT), year: 2020
# Canceled, year: 2020
# Canceled, year: 2020
# W, 1-0, year: 2020
# W, 4-1, year: 2021
# W, 1-0, year: 2021
# L, 4-0, year: 2021

# %%
len(opponent_list) - len(result_list)
# Out:
# 17

# %%
miz_hist_schedule['opponent'] = opponent_list[:-17]
miz_hist_schedule['game_full_date'] = date_list[:-17]
miz_hist_schedule['game_year'] = year_list[:-17]
miz_hist_schedule['game_result'] = result_list

miz_hist_schedule[['game_date','game_full_date']] = miz_hist_schedule['game_full_date'].str.split("(",expand=True)
miz_hist_schedule[['game_day_of_week','game_time']] = miz_hist_schedule['game_full_date'].str.split(")",expand=True)

# %%
miz_hist_schedule = miz_hist_schedule.drop(columns = ['game_full_date'])

# %%
miz_hist_schedule.head(235)
# Out:
#                      opponent game_year game_result game_date  \
# 0       Illinois (Exhibition)      2010      T, 2-2   Aug 13
# 1                     Belmont      2010    Canceled   Aug 20
# 2                #16 Maryland      2010      L, 3-2   Aug 22
# 3                    #25 Duke      2010      L, 3-1   Aug 27
# 4           #1 North Carolina      2010      L, 6-1   Aug 29
# ..                        ...       ...         ...       ...
# 230                Notre Dame      2020    Canceled    Apr 2
# 231                    Kansas      2020      W, 1-0   Apr 10
# 232                    Kansas      2020      W, 4-1   Apr 17
# 233  Sam Houston State (Exh.)      2021      W, 1-0   Aug 10
# 234     Oklahoma State (Exh.)      2021      L, 4-0   Aug 13
#
#     game_day_of_week   game_time
# 0                Fri      1:00PM
# 1                Fri      6:30PM
# 2                Sun     11:00AM
# 3                Fri      4:00PM
# 4                Sun      1:00PM
# ..               ...         ...
# 230              Fri   1 p.m. CT
# 231              Sat   1 p.m. CT
# 232              Sat   7 p.m. CT
# 233              Tue        7 PM
# 234              Fri       10 AM
#
# [235 rows x 6 columns]

# %%
miz_hist_schedule['game_day_of_week'].value_counts()
# Out:
# Thu    10
# Sun    10
# Fri     7
# Sat     6
# Tue     2
# Wed     1
# Name: game_day_of_week, dtype: int64
